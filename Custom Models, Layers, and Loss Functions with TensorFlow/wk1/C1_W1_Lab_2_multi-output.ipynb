# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 220.1387 - y1_output_loss: 106.5403 - y2_output_loss: 111.8491 - y1_output_root_mean_squared_error: 10.3642 - y2_output_root_mean_squared_error: 10.6171 - val_loss: 42.4678 - val_y1_output_loss: 18.8464 - val_y2_output_loss: 22.3902 - val_y1_output_root_mean_squared_error: 4.4141 - val_y2_output_root_mean_squared_error: 4.7941
# Epoch 2/500
# 614/614 [==============================] - 0s 175us/sample - loss: 37.5740 - y1_output_loss: 13.2338 - y2_output_loss: 24.0102 - y1_output_root_mean_squared_error: 3.6534 - y2_output_root_mean_squared_error: 4.9220 - val_loss: 30.6388 - val_y1_output_loss: 13.0715 - val_y2_output_loss: 17.1192 - val_y1_output_root_mean_squared_error: 3.6578 - val_y2_output_root_mean_squared_error: 4.1545
# Epoch 3/500
# 614/614 [==============================] - 0s 186us/sample - loss: 28.0735 - y1_output_loss: 10.8599 - y2_output_loss: 17.0536 - y1_output_root_mean_squared_error: 3.3022 - y2_output_root_mean_squared_error: 4.1435 - val_loss: 41.3970 - val_y1_output_loss: 14.2098 - val_y2_output_loss: 26.3089 - val_y1_output_root_mean_squared_error: 3.7989 - val_y2_output_root_mean_squared_error: 5.1929
# Epoch 4/500
# 614/614 [==============================] - 0s 170us/sample - loss: 22.6184 - y1_output_loss: 9.0326 - y2_output_loss: 13.4066 - y1_output_root_mean_squared_error: 3.0179 - y2_output_root_mean_squared_error: 3.6757 - val_loss: 20.6909 - val_y1_output_loss: 8.7091 - val_y2_output_loss: 11.6401 - val_y1_output_root_mean_squared_error: 2.9968 - val_y2_output_root_mean_squared_error: 3.4220
# Epoch 5/500
# 614/614 [==============================] - 0s 168us/sample - loss: 24.6765 - y1_output_loss: 9.3804 - y2_output_loss: 15.0999 - y1_output_root_mean_squared_error: 3.0767 - y2_output_root_mean_squared_error: 3.9001 - val_loss: 23.1653 - val_y1_output_loss: 10.4120 - val_y2_output_loss: 12.2317 - val_y1_output_root_mean_squared_error: 3.2699 - val_y2_output_root_mean_squared_error: 3.5318
# Epoch 6/500
# 614/614 [==============================] - 0s 179us/sample - loss: 25.3605 - y1_output_loss: 9.5352 - y2_output_loss: 16.0516 - y1_output_root_mean_squared_error: 3.0936 - y2_output_root_mean_squared_error: 3.9737 - val_loss: 29.8358 - val_y1_output_loss: 9.5445 - val_y2_output_loss: 19.4897 - val_y1_output_root_mean_squared_error: 3.1223 - val_y2_output_root_mean_squared_error: 4.4818
# Epoch 7/500
# 614/614 [==============================] - 0s 171us/sample - loss: 20.6496 - y1_output_loss: 8.2340 - y2_output_loss: 12.4011 - y1_output_root_mean_squared_error: 2.8681 - y2_output_root_mean_squared_error: 3.5247 - val_loss: 20.8963 - val_y1_output_loss: 9.2579 - val_y2_output_loss: 11.4326 - val_y1_output_root_mean_squared_error: 3.0738 - val_y2_output_root_mean_squared_error: 3.3835
# Epoch 8/500
# 614/614 [==============================] - 0s 177us/sample - loss: 22.2341 - y1_output_loss: 8.3759 - y2_output_loss: 13.8473 - y1_output_root_mean_squared_error: 2.8975 - y2_output_root_mean_squared_error: 3.7200 - val_loss: 47.3167 - val_y1_output_loss: 10.7575 - val_y2_output_loss: 35.2225 - val_y1_output_root_mean_squared_error: 3.3238 - val_y2_output_root_mean_squared_error: 6.0224
# Epoch 9/500
# 614/614 [==============================] - 0s 171us/sample - loss: 29.6557 - y1_output_loss: 9.7170 - y2_output_loss: 19.6621 - y1_output_root_mean_squared_error: 3.1322 - y2_output_root_mean_squared_error: 4.4548 - val_loss: 18.4508 - val_y1_output_loss: 8.1916 - val_y2_output_loss: 9.8967 - val_y1_output_root_mean_squared_error: 2.8992 - val_y2_output_root_mean_squared_error: 3.1695
# Epoch 10/500
# 614/614 [==============================] - 0s 161us/sample - loss: 20.3647 - y1_output_loss: 8.1267 - y2_output_loss: 12.1816 - y1_output_root_mean_squared_error: 2.8452 - y2_output_root_mean_squared_error: 3.5028 - val_loss: 20.2181 - val_y1_output_loss: 9.0061 - val_y2_output_loss: 10.8481 - val_y1_output_root_mean_squared_error: 3.0367 - val_y2_output_root_mean_squared_error: 3.3161
# Epoch 11/500
# 614/614 [==============================] - 0s 186us/sample - loss: 17.8156 - y1_output_loss: 7.2581 - y2_output_loss: 10.4561 - y1_output_root_mean_squared_error: 2.7036 - y2_output_root_mean_squared_error: 3.2414 - val_loss: 16.1994 - val_y1_output_loss: 6.9951 - val_y2_output_loss: 9.0274 - val_y1_output_root_mean_squared_error: 2.6699 - val_y2_output_root_mean_squared_error: 3.0118
# Epoch 12/500
# 614/614 [==============================] - 0s 165us/sample - loss: 19.6168 - y1_output_loss: 7.5454 - y2_output_loss: 11.9683 - y1_output_root_mean_squared_error: 2.7570 - y2_output_root_mean_squared_error: 3.4663 - val_loss: 18.6835 - val_y1_output_loss: 7.8178 - val_y2_output_loss: 10.7081 - val_y1_output_root_mean_squared_error: 2.8233 - val_y2_output_root_mean_squared_error: 3.2730
# Epoch 13/500
# 614/614 [==============================] - 0s 170us/sample - loss: 18.5240 - y1_output_loss: 7.2254 - y2_output_loss: 11.2269 - y1_output_root_mean_squared_error: 2.6941 - y2_output_root_mean_squared_error: 3.3564 - val_loss: 19.5351 - val_y1_output_loss: 8.6734 - val_y2_output_loss: 10.3944 - val_y1_output_root_mean_squared_error: 2.9954 - val_y2_output_root_mean_squared_error: 3.2501
# Epoch 14/500
# 614/614 [==============================] - 0s 165us/sample - loss: 17.6994 - y1_output_loss: 6.6484 - y2_output_loss: 10.9421 - y1_output_root_mean_squared_error: 2.5865 - y2_output_root_mean_squared_error: 3.3180 - val_loss: 18.2834 - val_y1_output_loss: 7.1201 - val_y2_output_loss: 10.6240 - val_y1_output_root_mean_squared_error: 2.7083 - val_y2_output_root_mean_squared_error: 3.3088
# Epoch 15/500
# 614/614 [==============================] - 0s 163us/sample - loss: 18.0554 - y1_output_loss: 7.0393 - y2_output_loss: 10.8980 - y1_output_root_mean_squared_error: 2.6608 - y2_output_root_mean_squared_error: 3.3129 - val_loss: 14.4263 - val_y1_output_loss: 6.2906 - val_y2_output_loss: 7.7095 - val_y1_output_root_mean_squared_error: 2.5504 - val_y2_output_root_mean_squared_error: 2.8146
# Epoch 16/500
# 614/614 [==============================] - 0s 181us/sample - loss: 14.5363 - y1_output_loss: 5.9332 - y2_output_loss: 8.7485 - y1_output_root_mean_squared_error: 2.4185 - y2_output_root_mean_squared_error: 2.9474 - val_loss: 30.9734 - val_y1_output_loss: 9.3213 - val_y2_output_loss: 21.7278 - val_y1_output_root_mean_squared_error: 3.0676 - val_y2_output_root_mean_squared_error: 4.6436
# Epoch 17/500
# 614/614 [==============================] - 0s 159us/sample - loss: 16.6249 - y1_output_loss: 6.3839 - y2_output_loss: 10.7742 - y1_output_root_mean_squared_error: 2.4820 - y2_output_root_mean_squared_error: 3.2349 - val_loss: 91.1764 - val_y1_output_loss: 19.5858 - val_y2_output_loss: 70.4330 - val_y1_output_root_mean_squared_error: 4.4829 - val_y2_output_root_mean_squared_error: 8.4309
# Epoch 18/500
# 614/614 [==============================] - 0s 159us/sample - loss: 17.3922 - y1_output_loss: 6.0633 - y2_output_loss: 11.2103 - y1_output_root_mean_squared_error: 2.4737 - y2_output_root_mean_squared_error: 3.3575 - val_loss: 18.6149 - val_y1_output_loss: 6.4888 - val_y2_output_loss: 11.6887 - val_y1_output_root_mean_squared_error: 2.5734 - val_y2_output_root_mean_squared_error: 3.4630
# Epoch 19/500
# 614/614 [==============================] - 0s 167us/sample - loss: 16.1109 - y1_output_loss: 5.8676 - y2_output_loss: 10.1671 - y1_output_root_mean_squared_error: 2.4228 - y2_output_root_mean_squared_error: 3.2002 - val_loss: 12.9096 - val_y1_output_loss: 5.5290 - val_y2_output_loss: 7.0736 - val_y1_output_root_mean_squared_error: 2.3862 - val_y2_output_root_mean_squared_error: 2.6862
# Epoch 20/500
# 614/614 [==============================] - 0s 159us/sample - loss: 13.5232 - y1_output_loss: 5.4327 - y2_output_loss: 8.0254 - y1_output_root_mean_squared_error: 2.3328 - y2_output_root_mean_squared_error: 2.8427 - val_loss: 14.4952 - val_y1_output_loss: 6.2981 - val_y2_output_loss: 7.7409 - val_y1_output_root_mean_squared_error: 2.5553 - val_y2_output_root_mean_squared_error: 2.8223
# Epoch 21/500
# 614/614 [==============================] - 0s 167us/sample - loss: 12.8869 - y1_output_loss: 4.8389 - y2_output_loss: 7.9547 - y1_output_root_mean_squared_error: 2.2067 - y2_output_root_mean_squared_error: 2.8315 - val_loss: 11.3493 - val_y1_output_loss: 4.7232 - val_y2_output_loss: 6.3193 - val_y1_output_root_mean_squared_error: 2.2052 - val_y2_output_root_mean_squared_error: 2.5469
# Epoch 22/500
# 614/614 [==============================] - 0s 174us/sample - loss: 11.8288 - y1_output_loss: 4.5585 - y2_output_loss: 7.3373 - y1_output_root_mean_squared_error: 2.1401 - y2_output_root_mean_squared_error: 2.6924 - val_loss: 14.2609 - val_y1_output_loss: 4.6342 - val_y2_output_loss: 9.1211 - val_y1_output_root_mean_squared_error: 2.1927 - val_y2_output_root_mean_squared_error: 3.0745
# Epoch 23/500
# 614/614 [==============================] - 0s 168us/sample - loss: 14.1771 - y1_output_loss: 5.1057 - y2_output_loss: 8.9916 - y1_output_root_mean_squared_error: 2.2678 - y2_output_root_mean_squared_error: 3.0057 - val_loss: 13.4567 - val_y1_output_loss: 5.4461 - val_y2_output_loss: 7.5881 - val_y1_output_root_mean_squared_error: 2.3765 - val_y2_output_root_mean_squared_error: 2.7944
# Epoch 24/500
# 614/614 [==============================] - 0s 180us/sample - loss: 13.1596 - y1_output_loss: 4.7617 - y2_output_loss: 8.3551 - y1_output_root_mean_squared_error: 2.1794 - y2_output_root_mean_squared_error: 2.8999 - val_loss: 26.8117 - val_y1_output_loss: 9.1802 - val_y2_output_loss: 17.1601 - val_y1_output_root_mean_squared_error: 3.0718 - val_y2_output_root_mean_squared_error: 4.1684
# Epoch 25/500
# 614/614 [==============================] - 0s 163us/sample - loss: 12.4066 - y1_output_loss: 4.7230 - y2_output_loss: 7.5746 - y1_output_root_mean_squared_error: 2.1835 - y2_output_root_mean_squared_error: 2.7639 - val_loss: 10.5547 - val_y1_output_loss: 4.2612 - val_y2_output_loss: 6.0235 - val_y1_output_root_mean_squared_error: 2.0958 - val_y2_output_root_mean_squared_error: 2.4824
# Epoch 26/500
# 614/614 [==============================] - 0s 163us/sample - loss: 10.8328 - y1_output_loss: 4.1199 - y2_output_loss: 6.7621 - y1_output_root_mean_squared_error: 2.0189 - y2_output_root_mean_squared_error: 2.5994 - val_loss: 31.8838 - val_y1_output_loss: 8.8961 - val_y2_output_loss: 22.4167 - val_y1_output_root_mean_squared_error: 3.0265 - val_y2_output_root_mean_squared_error: 4.7670
# Epoch 27/500
# 614/614 [==============================] - 0s 170us/sample - loss: 14.0517 - y1_output_loss: 4.5960 - y2_output_loss: 9.3997 - y1_output_root_mean_squared_error: 2.1492 - y2_output_root_mean_squared_error: 3.0713 - val_loss: 13.1815 - val_y1_output_loss: 4.5817 - val_y2_output_loss: 8.1412 - val_y1_output_root_mean_squared_error: 2.1773 - val_y2_output_root_mean_squared_error: 2.9053
# Epoch 28/500
# 614/614 [==============================] - 0s 161us/sample - loss: 11.8928 - y1_output_loss: 4.1653 - y2_output_loss: 7.7889 - y1_output_root_mean_squared_error: 2.0259 - y2_output_root_mean_squared_error: 2.7908 - val_loss: 10.5989 - val_y1_output_loss: 4.1925 - val_y2_output_loss: 6.1082 - val_y1_output_root_mean_squared_error: 2.0788 - val_y2_output_root_mean_squared_error: 2.5055
# Epoch 29/500
# 614/614 [==============================] - 0s 187us/sample - loss: 11.9704 - y1_output_loss: 4.0285 - y2_output_loss: 7.8789 - y1_output_root_mean_squared_error: 2.0060 - y2_output_root_mean_squared_error: 2.8189 - val_loss: 9.6533 - val_y1_output_loss: 3.6137 - val_y2_output_loss: 5.7566 - val_y1_output_root_mean_squared_error: 1.9328 - val_y2_output_root_mean_squared_error: 2.4326
# Epoch 30/500
# 614/614 [==============================] - 0s 177us/sample - loss: 9.6993 - y1_output_loss: 3.4829 - y2_output_loss: 6.1929 - y1_output_root_mean_squared_error: 1.8576 - y2_output_root_mean_squared_error: 2.4997 - val_loss: 16.2632 - val_y1_output_loss: 6.1585 - val_y2_output_loss: 9.7408 - val_y1_output_root_mean_squared_error: 2.5194 - val_y2_output_root_mean_squared_error: 3.1490
# Epoch 31/500
# 614/614 [==============================] - 0s 174us/sample - loss: 9.4896 - y1_output_loss: 3.3749 - y2_output_loss: 6.1550 - y1_output_root_mean_squared_error: 1.8287 - y2_output_root_mean_squared_error: 2.4790 - val_loss: 23.2904 - val_y1_output_loss: 8.0560 - val_y2_output_loss: 14.5812 - val_y1_output_root_mean_squared_error: 2.8887 - val_y2_output_root_mean_squared_error: 3.8659
# Epoch 32/500
# 614/614 [==============================] - 0s 183us/sample - loss: 10.0511 - y1_output_loss: 3.5276 - y2_output_loss: 6.5546 - y1_output_root_mean_squared_error: 1.8797 - y2_output_root_mean_squared_error: 2.5530 - val_loss: 26.7678 - val_y1_output_loss: 7.4615 - val_y2_output_loss: 18.8680 - val_y1_output_root_mean_squared_error: 2.7672 - val_y2_output_root_mean_squared_error: 4.3716
# Epoch 33/500
# 614/614 [==============================] - 0s 167us/sample - loss: 11.5429 - y1_output_loss: 3.7394 - y2_output_loss: 7.6958 - y1_output_root_mean_squared_error: 1.9424 - y2_output_root_mean_squared_error: 2.7875 - val_loss: 8.2801 - val_y1_output_loss: 2.9644 - val_y2_output_loss: 5.0587 - val_y1_output_root_mean_squared_error: 1.7545 - val_y2_output_root_mean_squared_error: 2.2807
# Epoch 34/500
# 614/614 [==============================] - 0s 183us/sample - loss: 8.5849 - y1_output_loss: 3.1070 - y2_output_loss: 5.4318 - y1_output_root_mean_squared_error: 1.7619 - y2_output_root_mean_squared_error: 2.3411 - val_loss: 10.2402 - val_y1_output_loss: 3.5654 - val_y2_output_loss: 6.3674 - val_y1_output_root_mean_squared_error: 1.9203 - val_y2_output_root_mean_squared_error: 2.5598
# Epoch 35/500
# 614/614 [==============================] - 0s 177us/sample - loss: 8.3280 - y1_output_loss: 2.8995 - y2_output_loss: 5.3826 - y1_output_root_mean_squared_error: 1.7087 - y2_output_root_mean_squared_error: 2.3256 - val_loss: 18.4884 - val_y1_output_loss: 4.9861 - val_y2_output_loss: 12.9821 - val_y1_output_root_mean_squared_error: 2.2596 - val_y2_output_root_mean_squared_error: 3.6582
# Epoch 36/500
# 614/614 [==============================] - 0s 163us/sample - loss: 9.6295 - y1_output_loss: 3.1935 - y2_output_loss: 6.3905 - y1_output_root_mean_squared_error: 1.7890 - y2_output_root_mean_squared_error: 2.5355 - val_loss: 19.5558 - val_y1_output_loss: 5.1918 - val_y2_output_loss: 13.7842 - val_y1_output_root_mean_squared_error: 2.3136 - val_y2_output_root_mean_squared_error: 3.7687
# Epoch 37/500
# 614/614 [==============================] - 0s 178us/sample - loss: 8.3548 - y1_output_loss: 2.8374 - y2_output_loss: 5.4677 - y1_output_root_mean_squared_error: 1.6899 - y2_output_root_mean_squared_error: 2.3450 - val_loss: 8.8502 - val_y1_output_loss: 2.7183 - val_y2_output_loss: 5.8233 - val_y1_output_root_mean_squared_error: 1.6788 - val_y2_output_root_mean_squared_error: 2.4560
# Epoch 38/500
# 614/614 [==============================] - 0s 162us/sample - loss: 6.9531 - y1_output_loss: 2.5086 - y2_output_loss: 4.4237 - y1_output_root_mean_squared_error: 1.5894 - y2_output_root_mean_squared_error: 2.1041 - val_loss: 9.3364 - val_y1_output_loss: 2.9957 - val_y2_output_loss: 6.0199 - val_y1_output_root_mean_squared_error: 1.7614 - val_y2_output_root_mean_squared_error: 2.4968
# Epoch 39/500
# 614/614 [==============================] - 0s 166us/sample - loss: 11.2778 - y1_output_loss: 3.3668 - y2_output_loss: 7.9598 - y1_output_root_mean_squared_error: 1.8330 - y2_output_root_mean_squared_error: 2.8139 - val_loss: 50.2354 - val_y1_output_loss: 15.5416 - val_y2_output_loss: 33.8320 - val_y1_output_root_mean_squared_error: 3.9854 - val_y2_output_root_mean_squared_error: 5.8611
# Epoch 40/500
# 614/614 [==============================] - 0s 178us/sample - loss: 9.3315 - y1_output_loss: 3.0161 - y2_output_loss: 6.2272 - y1_output_root_mean_squared_error: 1.7450 - y2_output_root_mean_squared_error: 2.5073 - val_loss: 8.3215 - val_y1_output_loss: 2.5195 - val_y2_output_loss: 5.5188 - val_y1_output_root_mean_squared_error: 1.6161 - val_y2_output_root_mean_squared_error: 2.3895
# Epoch 41/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.5644 - y1_output_loss: 2.3606 - y2_output_loss: 5.1719 - y1_output_root_mean_squared_error: 1.5438 - y2_output_root_mean_squared_error: 2.2762 - val_loss: 8.1353 - val_y1_output_loss: 2.4724 - val_y2_output_loss: 5.4338 - val_y1_output_root_mean_squared_error: 1.5931 - val_y2_output_root_mean_squared_error: 2.3659
# Epoch 42/500
# 614/614 [==============================] - 0s 175us/sample - loss: 7.9616 - y1_output_loss: 2.5846 - y2_output_loss: 5.3660 - y1_output_root_mean_squared_error: 1.5985 - y2_output_root_mean_squared_error: 2.3252 - val_loss: 9.5064 - val_y1_output_loss: 3.1040 - val_y2_output_loss: 6.0592 - val_y1_output_root_mean_squared_error: 1.7945 - val_y2_output_root_mean_squared_error: 2.5073
# Epoch 43/500
# 614/614 [==============================] - 0s 176us/sample - loss: 7.8411 - y1_output_loss: 2.4912 - y2_output_loss: 5.2976 - y1_output_root_mean_squared_error: 1.5814 - y2_output_root_mean_squared_error: 2.3109 - val_loss: 11.0747 - val_y1_output_loss: 3.4904 - val_y2_output_loss: 7.4367 - val_y1_output_root_mean_squared_error: 1.8903 - val_y2_output_root_mean_squared_error: 2.7389
# Epoch 44/500
# 614/614 [==============================] - 0s 165us/sample - loss: 6.7494 - y1_output_loss: 2.2158 - y2_output_loss: 4.4857 - y1_output_root_mean_squared_error: 1.4957 - y2_output_root_mean_squared_error: 2.1242 - val_loss: 10.5189 - val_y1_output_loss: 3.1521 - val_y2_output_loss: 7.1530 - val_y1_output_root_mean_squared_error: 1.7988 - val_y2_output_root_mean_squared_error: 2.6987
# Epoch 45/500
# 614/614 [==============================] - 0s 191us/sample - loss: 9.6926 - y1_output_loss: 2.8687 - y2_output_loss: 6.7752 - y1_output_root_mean_squared_error: 1.6895 - y2_output_root_mean_squared_error: 2.6150 - val_loss: 9.6823 - val_y1_output_loss: 3.0087 - val_y2_output_loss: 6.4898 - val_y1_output_root_mean_squared_error: 1.7602 - val_y2_output_root_mean_squared_error: 2.5659
# Epoch 46/500
# 614/614 [==============================] - 0s 183us/sample - loss: 7.2492 - y1_output_loss: 2.3008 - y2_output_loss: 4.8860 - y1_output_root_mean_squared_error: 1.5239 - y2_output_root_mean_squared_error: 2.2196 - val_loss: 10.4720 - val_y1_output_loss: 2.7669 - val_y2_output_loss: 7.4136 - val_y1_output_root_mean_squared_error: 1.6794 - val_y2_output_root_mean_squared_error: 2.7662
# Epoch 47/500
# 614/614 [==============================] - 0s 175us/sample - loss: 8.9705 - y1_output_loss: 2.9376 - y2_output_loss: 5.9754 - y1_output_root_mean_squared_error: 1.7192 - y2_output_root_mean_squared_error: 2.4525 - val_loss: 6.7606 - val_y1_output_loss: 2.0421 - val_y2_output_loss: 4.5191 - val_y1_output_root_mean_squared_error: 1.4544 - val_y2_output_root_mean_squared_error: 2.1553
# Epoch 48/500
# 614/614 [==============================] - 0s 177us/sample - loss: 7.9117 - y1_output_loss: 2.6107 - y2_output_loss: 5.5046 - y1_output_root_mean_squared_error: 1.5728 - y2_output_root_mean_squared_error: 2.3319 - val_loss: 38.0978 - val_y1_output_loss: 14.1534 - val_y2_output_loss: 23.0422 - val_y1_output_root_mean_squared_error: 3.8182 - val_y2_output_root_mean_squared_error: 4.8497
# Epoch 49/500
# 614/614 [==============================] - 0s 172us/sample - loss: 8.4909 - y1_output_loss: 2.8605 - y2_output_loss: 5.6223 - y1_output_root_mean_squared_error: 1.6933 - y2_output_root_mean_squared_error: 2.3715 - val_loss: 8.1198 - val_y1_output_loss: 2.4596 - val_y2_output_loss: 5.3813 - val_y1_output_root_mean_squared_error: 1.5936 - val_y2_output_root_mean_squared_error: 2.3623
# Epoch 50/500
# 614/614 [==============================] - 0s 173us/sample - loss: 7.2710 - y1_output_loss: 2.3406 - y2_output_loss: 4.9549 - y1_output_root_mean_squared_error: 1.5266 - y2_output_root_mean_squared_error: 2.2227 - val_loss: 8.5148 - val_y1_output_loss: 2.5192 - val_y2_output_loss: 5.7199 - val_y1_output_root_mean_squared_error: 1.6124 - val_y2_output_root_mean_squared_error: 2.4321
# Epoch 51/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.6826 - y1_output_loss: 2.1298 - y2_output_loss: 4.5044 - y1_output_root_mean_squared_error: 1.4615 - y2_output_root_mean_squared_error: 2.1323 - val_loss: 9.8719 - val_y1_output_loss: 2.7542 - val_y2_output_loss: 6.9868 - val_y1_output_root_mean_squared_error: 1.6755 - val_y2_output_root_mean_squared_error: 2.6579
# Epoch 52/500
# 614/614 [==============================] - 0s 164us/sample - loss: 6.3027 - y1_output_loss: 2.0671 - y2_output_loss: 4.2094 - y1_output_root_mean_squared_error: 1.4346 - y2_output_root_mean_squared_error: 2.0603 - val_loss: 6.4454 - val_y1_output_loss: 1.9372 - val_y2_output_loss: 4.2937 - val_y1_output_root_mean_squared_error: 1.4163 - val_y2_output_root_mean_squared_error: 2.1070
# Epoch 53/500
# 614/614 [==============================] - 0s 182us/sample - loss: 7.3575 - y1_output_loss: 2.2083 - y2_output_loss: 5.1114 - y1_output_root_mean_squared_error: 1.4830 - y2_output_root_mean_squared_error: 2.2712 - val_loss: 9.6980 - val_y1_output_loss: 3.6453 - val_y2_output_loss: 6.0304 - val_y1_output_root_mean_squared_error: 1.9093 - val_y2_output_root_mean_squared_error: 2.4602
# Epoch 54/500
# 614/614 [==============================] - 0s 164us/sample - loss: 8.6761 - y1_output_loss: 2.4759 - y2_output_loss: 6.1530 - y1_output_root_mean_squared_error: 1.5808 - y2_output_root_mean_squared_error: 2.4854 - val_loss: 7.0981 - val_y1_output_loss: 1.7150 - val_y2_output_loss: 5.1424 - val_y1_output_root_mean_squared_error: 1.3295 - val_y2_output_root_mean_squared_error: 2.3088
# Epoch 55/500
# 614/614 [==============================] - 0s 191us/sample - loss: 6.2533 - y1_output_loss: 1.9378 - y2_output_loss: 4.3076 - y1_output_root_mean_squared_error: 1.3908 - y2_output_root_mean_squared_error: 2.0782 - val_loss: 10.2775 - val_y1_output_loss: 2.5416 - val_y2_output_loss: 7.3669 - val_y1_output_root_mean_squared_error: 1.6243 - val_y2_output_root_mean_squared_error: 2.7639
# Epoch 56/500
# 614/614 [==============================] - 0s 158us/sample - loss: 6.5725 - y1_output_loss: 2.2051 - y2_output_loss: 4.3952 - y1_output_root_mean_squared_error: 1.4881 - y2_output_root_mean_squared_error: 2.0876 - val_loss: 7.4056 - val_y1_output_loss: 2.1256 - val_y2_output_loss: 5.0461 - val_y1_output_root_mean_squared_error: 1.4815 - val_y2_output_root_mean_squared_error: 2.2827
# Epoch 57/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.8260 - y1_output_loss: 1.7936 - y2_output_loss: 4.0016 - y1_output_root_mean_squared_error: 1.3443 - y2_output_root_mean_squared_error: 2.0047 - val_loss: 11.8281 - val_y1_output_loss: 2.5148 - val_y2_output_loss: 9.2504 - val_y1_output_root_mean_squared_error: 1.5913 - val_y2_output_root_mean_squared_error: 3.0489
# Epoch 58/500
# 614/614 [==============================] - 0s 193us/sample - loss: 7.4210 - y1_output_loss: 2.0448 - y2_output_loss: 5.3302 - y1_output_root_mean_squared_error: 1.4297 - y2_output_root_mean_squared_error: 2.3188 - val_loss: 7.7879 - val_y1_output_loss: 2.2061 - val_y2_output_loss: 5.3972 - val_y1_output_root_mean_squared_error: 1.5008 - val_y2_output_root_mean_squared_error: 2.3527
# Epoch 59/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.8901 - y1_output_loss: 1.8566 - y2_output_loss: 4.0196 - y1_output_root_mean_squared_error: 1.3650 - y2_output_root_mean_squared_error: 2.0067 - val_loss: 8.2455 - val_y1_output_loss: 2.8442 - val_y2_output_loss: 5.1657 - val_y1_output_root_mean_squared_error: 1.7103 - val_y2_output_root_mean_squared_error: 2.3066
# Epoch 60/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.0556 - y1_output_loss: 2.1776 - y2_output_loss: 4.8245 - y1_output_root_mean_squared_error: 1.4809 - y2_output_root_mean_squared_error: 2.2051 - val_loss: 8.1380 - val_y1_output_loss: 2.1400 - val_y2_output_loss: 5.8592 - val_y1_output_root_mean_squared_error: 1.4792 - val_y2_output_root_mean_squared_error: 2.4393
# Epoch 61/500
# 614/614 [==============================] - 0s 171us/sample - loss: 6.3674 - y1_output_loss: 1.9133 - y2_output_loss: 4.6026 - y1_output_root_mean_squared_error: 1.3788 - y2_output_root_mean_squared_error: 2.1134 - val_loss: 30.5352 - val_y1_output_loss: 8.5051 - val_y2_output_loss: 20.9507 - val_y1_output_root_mean_squared_error: 2.9701 - val_y2_output_root_mean_squared_error: 4.6598
# Epoch 62/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.7622 - y1_output_loss: 1.7378 - y2_output_loss: 4.0802 - y1_output_root_mean_squared_error: 1.3058 - y2_output_root_mean_squared_error: 2.0142 - val_loss: 7.3285 - val_y1_output_loss: 1.7129 - val_y2_output_loss: 5.3552 - val_y1_output_root_mean_squared_error: 1.3328 - val_y2_output_root_mean_squared_error: 2.3563
# Epoch 63/500
# 614/614 [==============================] - 0s 165us/sample - loss: 7.5184 - y1_output_loss: 2.1032 - y2_output_loss: 5.4082 - y1_output_root_mean_squared_error: 1.4556 - y2_output_root_mean_squared_error: 2.3237 - val_loss: 6.3194 - val_y1_output_loss: 1.6590 - val_y2_output_loss: 4.4479 - val_y1_output_root_mean_squared_error: 1.3110 - val_y2_output_root_mean_squared_error: 2.1449
# Epoch 64/500
# 614/614 [==============================] - 0s 174us/sample - loss: 7.7704 - y1_output_loss: 2.2491 - y2_output_loss: 5.5070 - y1_output_root_mean_squared_error: 1.4984 - y2_output_root_mean_squared_error: 2.3506 - val_loss: 9.0746 - val_y1_output_loss: 2.7619 - val_y2_output_loss: 6.1241 - val_y1_output_root_mean_squared_error: 1.6798 - val_y2_output_root_mean_squared_error: 2.5006
# Epoch 65/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.3516 - y1_output_loss: 1.7119 - y2_output_loss: 3.6072 - y1_output_root_mean_squared_error: 1.3084 - y2_output_root_mean_squared_error: 1.9078 - val_loss: 7.0724 - val_y1_output_loss: 1.7392 - val_y2_output_loss: 5.1864 - val_y1_output_root_mean_squared_error: 1.3380 - val_y2_output_root_mean_squared_error: 2.2983
# Epoch 66/500
# 614/614 [==============================] - 0s 173us/sample - loss: 6.3015 - y1_output_loss: 1.7409 - y2_output_loss: 4.6003 - y1_output_root_mean_squared_error: 1.3183 - y2_output_root_mean_squared_error: 2.1363 - val_loss: 28.5308 - val_y1_output_loss: 5.8595 - val_y2_output_loss: 21.7617 - val_y1_output_root_mean_squared_error: 2.4643 - val_y2_output_root_mean_squared_error: 4.7390
# Epoch 67/500
# 614/614 [==============================] - 0s 157us/sample - loss: 6.1375 - y1_output_loss: 1.8532 - y2_output_loss: 4.2571 - y1_output_root_mean_squared_error: 1.3563 - y2_output_root_mean_squared_error: 2.0731 - val_loss: 6.5526 - val_y1_output_loss: 1.7396 - val_y2_output_loss: 4.6922 - val_y1_output_root_mean_squared_error: 1.3289 - val_y2_output_root_mean_squared_error: 2.1878
# Epoch 68/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.9536 - y1_output_loss: 1.7938 - y2_output_loss: 4.2167 - y1_output_root_mean_squared_error: 1.3298 - y2_output_root_mean_squared_error: 2.0458 - val_loss: 19.9625 - val_y1_output_loss: 8.9725 - val_y2_output_loss: 10.4068 - val_y1_output_root_mean_squared_error: 3.0426 - val_y2_output_root_mean_squared_error: 3.2719
# Epoch 69/500
# 614/614 [==============================] - 0s 183us/sample - loss: 7.4106 - y1_output_loss: 2.1891 - y2_output_loss: 5.2315 - y1_output_root_mean_squared_error: 1.4766 - y2_output_root_mean_squared_error: 2.2870 - val_loss: 6.3956 - val_y1_output_loss: 1.6367 - val_y2_output_loss: 4.5450 - val_y1_output_root_mean_squared_error: 1.3009 - val_y2_output_root_mean_squared_error: 2.1687
# Epoch 70/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.0652 - y1_output_loss: 1.6388 - y2_output_loss: 4.3939 - y1_output_root_mean_squared_error: 1.2849 - y2_output_root_mean_squared_error: 2.1010 - val_loss: 6.1863 - val_y1_output_loss: 1.6788 - val_y2_output_loss: 4.3777 - val_y1_output_root_mean_squared_error: 1.3124 - val_y2_output_root_mean_squared_error: 2.1128
# Epoch 71/500
# 614/614 [==============================] - 0s 185us/sample - loss: 5.2286 - y1_output_loss: 1.4983 - y2_output_loss: 3.7052 - y1_output_root_mean_squared_error: 1.2250 - y2_output_root_mean_squared_error: 1.9308 - val_loss: 5.4681 - val_y1_output_loss: 1.3965 - val_y2_output_loss: 3.9663 - val_y1_output_root_mean_squared_error: 1.1925 - val_y2_output_root_mean_squared_error: 2.0115
# Epoch 72/500
# 614/614 [==============================] - 0s 169us/sample - loss: 5.1371 - y1_output_loss: 1.5480 - y2_output_loss: 3.6766 - y1_output_root_mean_squared_error: 1.2246 - y2_output_root_mean_squared_error: 1.9072 - val_loss: 17.5959 - val_y1_output_loss: 5.0770 - val_y2_output_loss: 12.4746 - val_y1_output_root_mean_squared_error: 2.2543 - val_y2_output_root_mean_squared_error: 3.5375
# Epoch 73/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.3693 - y1_output_loss: 1.6952 - y2_output_loss: 3.6494 - y1_output_root_mean_squared_error: 1.3021 - y2_output_root_mean_squared_error: 1.9168 - val_loss: 7.0534 - val_y1_output_loss: 1.7983 - val_y2_output_loss: 5.1286 - val_y1_output_root_mean_squared_error: 1.3577 - val_y2_output_root_mean_squared_error: 2.2826
# Epoch 74/500
# 614/614 [==============================] - 0s 179us/sample - loss: 7.0293 - y1_output_loss: 2.0111 - y2_output_loss: 4.9621 - y1_output_root_mean_squared_error: 1.4213 - y2_output_root_mean_squared_error: 2.2382 - val_loss: 5.9287 - val_y1_output_loss: 1.7980 - val_y2_output_loss: 4.0032 - val_y1_output_root_mean_squared_error: 1.3510 - val_y2_output_root_mean_squared_error: 2.0257
# Epoch 75/500
# 614/614 [==============================] - 0s 163us/sample - loss: 4.9494 - y1_output_loss: 1.5303 - y2_output_loss: 3.3999 - y1_output_root_mean_squared_error: 1.2366 - y2_output_root_mean_squared_error: 1.8494 - val_loss: 5.8550 - val_y1_output_loss: 1.5836 - val_y2_output_loss: 4.0857 - val_y1_output_root_mean_squared_error: 1.2732 - val_y2_output_root_mean_squared_error: 2.0577
# Epoch 76/500
# 614/614 [==============================] - 0s 174us/sample - loss: 6.7157 - y1_output_loss: 1.8726 - y2_output_loss: 4.8054 - y1_output_root_mean_squared_error: 1.3732 - y2_output_root_mean_squared_error: 2.1977 - val_loss: 7.8934 - val_y1_output_loss: 2.2609 - val_y2_output_loss: 5.4302 - val_y1_output_root_mean_squared_error: 1.5246 - val_y2_output_root_mean_squared_error: 2.3599
# Epoch 77/500
# 614/614 [==============================] - 0s 198us/sample - loss: 5.9601 - y1_output_loss: 1.8228 - y2_output_loss: 4.2128 - y1_output_root_mean_squared_error: 1.3518 - y2_output_root_mean_squared_error: 2.0329 - val_loss: 5.7379 - val_y1_output_loss: 1.5280 - val_y2_output_loss: 4.1121 - val_y1_output_root_mean_squared_error: 1.2384 - val_y2_output_root_mean_squared_error: 2.0505
# Epoch 78/500
# 614/614 [==============================] - 0s 170us/sample - loss: 8.3541 - y1_output_loss: 2.2699 - y2_output_loss: 6.0337 - y1_output_root_mean_squared_error: 1.5067 - y2_output_root_mean_squared_error: 2.4666 - val_loss: 5.9090 - val_y1_output_loss: 1.4616 - val_y2_output_loss: 4.3275 - val_y1_output_root_mean_squared_error: 1.2196 - val_y2_output_root_mean_squared_error: 2.1028
# Epoch 79/500
# 614/614 [==============================] - 0s 192us/sample - loss: 4.3121 - y1_output_loss: 1.2670 - y2_output_loss: 3.0152 - y1_output_root_mean_squared_error: 1.1293 - y2_output_root_mean_squared_error: 1.7426 - val_loss: 5.4528 - val_y1_output_loss: 1.4198 - val_y2_output_loss: 3.9571 - val_y1_output_root_mean_squared_error: 1.1937 - val_y2_output_root_mean_squared_error: 2.0070
# Epoch 80/500
# 614/614 [==============================] - 0s 192us/sample - loss: 5.6988 - y1_output_loss: 1.6257 - y2_output_loss: 4.1413 - y1_output_root_mean_squared_error: 1.2749 - y2_output_root_mean_squared_error: 2.0183 - val_loss: 30.6261 - val_y1_output_loss: 7.0942 - val_y2_output_loss: 23.1290 - val_y1_output_root_mean_squared_error: 2.6839 - val_y2_output_root_mean_squared_error: 4.8397
# Epoch 81/500
# 614/614 [==============================] - 0s 169us/sample - loss: 5.8035 - y1_output_loss: 1.7418 - y2_output_loss: 4.1106 - y1_output_root_mean_squared_error: 1.3146 - y2_output_root_mean_squared_error: 2.0187 - val_loss: 9.6241 - val_y1_output_loss: 3.0594 - val_y2_output_loss: 6.2352 - val_y1_output_root_mean_squared_error: 1.7776 - val_y2_output_root_mean_squared_error: 2.5425
# Epoch 82/500
# 614/614 [==============================] - 0s 171us/sample - loss: 4.8351 - y1_output_loss: 1.3864 - y2_output_loss: 3.4580 - y1_output_root_mean_squared_error: 1.1796 - y2_output_root_mean_squared_error: 1.8557 - val_loss: 7.0520 - val_y1_output_loss: 1.8916 - val_y2_output_loss: 4.9178 - val_y1_output_root_mean_squared_error: 1.3982 - val_y2_output_root_mean_squared_error: 2.2577
# Epoch 83/500
# 614/614 [==============================] - 0s 159us/sample - loss: 4.6287 - y1_output_loss: 1.3038 - y2_output_loss: 3.3191 - y1_output_root_mean_squared_error: 1.1464 - y2_output_root_mean_squared_error: 1.8206 - val_loss: 11.0186 - val_y1_output_loss: 1.9173 - val_y2_output_loss: 8.7777 - val_y1_output_root_mean_squared_error: 1.3995 - val_y2_output_root_mean_squared_error: 3.0100
# Epoch 84/500
# 614/614 [==============================] - 0s 182us/sample - loss: 4.6667 - y1_output_loss: 1.3355 - y2_output_loss: 3.3140 - y1_output_root_mean_squared_error: 1.1532 - y2_output_root_mean_squared_error: 1.8267 - val_loss: 4.7206 - val_y1_output_loss: 1.0166 - val_y2_output_loss: 3.5956 - val_y1_output_root_mean_squared_error: 1.0204 - val_y2_output_root_mean_squared_error: 1.9182
# Epoch 85/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.6847 - y1_output_loss: 1.3555 - y2_output_loss: 3.2909 - y1_output_root_mean_squared_error: 1.1697 - y2_output_root_mean_squared_error: 1.8211 - val_loss: 11.3733 - val_y1_output_loss: 2.6427 - val_y2_output_loss: 8.3266 - val_y1_output_root_mean_squared_error: 1.6563 - val_y2_output_root_mean_squared_error: 2.9377
# Epoch 86/500
# 614/614 [==============================] - 0s 163us/sample - loss: 8.9862 - y1_output_loss: 2.9232 - y2_output_loss: 6.1481 - y1_output_root_mean_squared_error: 1.7083 - y2_output_root_mean_squared_error: 2.4633 - val_loss: 23.0544 - val_y1_output_loss: 5.5725 - val_y2_output_loss: 16.7359 - val_y1_output_root_mean_squared_error: 2.4000 - val_y2_output_root_mean_squared_error: 4.1586
# Epoch 87/500
# 614/614 [==============================] - 0s 185us/sample - loss: 4.7517 - y1_output_loss: 1.3515 - y2_output_loss: 3.5565 - y1_output_root_mean_squared_error: 1.1548 - y2_output_root_mean_squared_error: 1.8488 - val_loss: 57.1241 - val_y1_output_loss: 9.4338 - val_y2_output_loss: 46.3021 - val_y1_output_root_mean_squared_error: 3.1158 - val_y2_output_root_mean_squared_error: 6.8859
# Epoch 88/500
# 614/614 [==============================] - 0s 187us/sample - loss: 4.8912 - y1_output_loss: 1.3937 - y2_output_loss: 3.4972 - y1_output_root_mean_squared_error: 1.1805 - y2_output_root_mean_squared_error: 1.8702 - val_loss: 12.6841 - val_y1_output_loss: 2.1422 - val_y2_output_loss: 10.4412 - val_y1_output_root_mean_squared_error: 1.4730 - val_y2_output_root_mean_squared_error: 3.2426
# Epoch 89/500
# 614/614 [==============================] - 0s 165us/sample - loss: 4.1046 - y1_output_loss: 1.0099 - y2_output_loss: 3.0765 - y1_output_root_mean_squared_error: 1.0001 - y2_output_root_mean_squared_error: 1.7619 - val_loss: 6.0495 - val_y1_output_loss: 1.1441 - val_y2_output_loss: 4.7886 - val_y1_output_root_mean_squared_error: 1.0858 - val_y2_output_root_mean_squared_error: 2.2069
# Epoch 90/500
# 614/614 [==============================] - 0s 181us/sample - loss: 3.7686 - y1_output_loss: 1.1497 - y2_output_loss: 2.6198 - y1_output_root_mean_squared_error: 1.0739 - y2_output_root_mean_squared_error: 1.6172 - val_loss: 5.4419 - val_y1_output_loss: 1.1565 - val_y2_output_loss: 4.0867 - val_y1_output_root_mean_squared_error: 1.0955 - val_y2_output_root_mean_squared_error: 2.0596
# Epoch 91/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.7271 - y1_output_loss: 1.0388 - y2_output_loss: 2.6672 - y1_output_root_mean_squared_error: 1.0198 - y2_output_root_mean_squared_error: 1.6392 - val_loss: 6.5870 - val_y1_output_loss: 1.5211 - val_y2_output_loss: 4.9771 - val_y1_output_root_mean_squared_error: 1.2401 - val_y2_output_root_mean_squared_error: 2.2470
# Epoch 92/500
# 614/614 [==============================] - 0s 174us/sample - loss: 4.1378 - y1_output_loss: 1.2265 - y2_output_loss: 2.8796 - y1_output_root_mean_squared_error: 1.1109 - y2_output_root_mean_squared_error: 1.7040 - val_loss: 7.6254 - val_y1_output_loss: 1.6139 - val_y2_output_loss: 5.8566 - val_y1_output_root_mean_squared_error: 1.2868 - val_y2_output_root_mean_squared_error: 2.4433
# Epoch 93/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.4744 - y1_output_loss: 0.7930 - y2_output_loss: 2.7089 - y1_output_root_mean_squared_error: 0.8891 - y2_output_root_mean_squared_error: 1.6383 - val_loss: 13.8768 - val_y1_output_loss: 3.7716 - val_y2_output_loss: 9.8294 - val_y1_output_root_mean_squared_error: 1.9652 - val_y2_output_root_mean_squared_error: 3.1646
# Epoch 94/500
# 614/614 [==============================] - 0s 163us/sample - loss: 4.4179 - y1_output_loss: 1.2160 - y2_output_loss: 3.2289 - y1_output_root_mean_squared_error: 1.0988 - y2_output_root_mean_squared_error: 1.7918 - val_loss: 3.9378 - val_y1_output_loss: 0.8617 - val_y2_output_loss: 2.9538 - val_y1_output_root_mean_squared_error: 0.9453 - val_y2_output_root_mean_squared_error: 1.7448
# Epoch 95/500
# 614/614 [==============================] - 0s 181us/sample - loss: 3.1236 - y1_output_loss: 0.8672 - y2_output_loss: 2.2517 - y1_output_root_mean_squared_error: 0.9261 - y2_output_root_mean_squared_error: 1.5053 - val_loss: 5.4315 - val_y1_output_loss: 0.8252 - val_y2_output_loss: 4.4862 - val_y1_output_root_mean_squared_error: 0.9231 - val_y2_output_root_mean_squared_error: 2.1400
# Epoch 96/500
# 614/614 [==============================] - 0s 175us/sample - loss: 3.4891 - y1_output_loss: 0.9135 - y2_output_loss: 2.5605 - y1_output_root_mean_squared_error: 0.9597 - y2_output_root_mean_squared_error: 1.6025 - val_loss: 4.7615 - val_y1_output_loss: 0.8738 - val_y2_output_loss: 3.7205 - val_y1_output_root_mean_squared_error: 0.9515 - val_y2_output_root_mean_squared_error: 1.9637
# Epoch 97/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.5947 - y1_output_loss: 0.8624 - y2_output_loss: 2.7261 - y1_output_root_mean_squared_error: 0.9274 - y2_output_root_mean_squared_error: 1.6537 - val_loss: 6.2952 - val_y1_output_loss: 1.1914 - val_y2_output_loss: 4.8787 - val_y1_output_root_mean_squared_error: 1.1120 - val_y2_output_root_mean_squared_error: 2.2491
# Epoch 98/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.4213 - y1_output_loss: 0.8158 - y2_output_loss: 2.5861 - y1_output_root_mean_squared_error: 0.9054 - y2_output_root_mean_squared_error: 1.6129 - val_loss: 4.8471 - val_y1_output_loss: 0.7593 - val_y2_output_loss: 3.9247 - val_y1_output_root_mean_squared_error: 0.8808 - val_y2_output_root_mean_squared_error: 2.0178
# Epoch 99/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.5369 - y1_output_loss: 0.9101 - y2_output_loss: 2.5953 - y1_output_root_mean_squared_error: 0.9580 - y2_output_root_mean_squared_error: 1.6184 - val_loss: 3.5936 - val_y1_output_loss: 0.6499 - val_y2_output_loss: 2.8408 - val_y1_output_root_mean_squared_error: 0.8175 - val_y2_output_root_mean_squared_error: 1.7103
# Epoch 100/500
# 614/614 [==============================] - 0s 182us/sample - loss: 3.1456 - y1_output_loss: 0.7297 - y2_output_loss: 2.4264 - y1_output_root_mean_squared_error: 0.8440 - y2_output_root_mean_squared_error: 1.5599 - val_loss: 3.6341 - val_y1_output_loss: 0.7019 - val_y2_output_loss: 2.8328 - val_y1_output_root_mean_squared_error: 0.8493 - val_y2_output_root_mean_squared_error: 1.7067
# Epoch 101/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.2605 - y1_output_loss: 0.7669 - y2_output_loss: 2.4676 - y1_output_root_mean_squared_error: 0.8781 - y2_output_root_mean_squared_error: 1.5778 - val_loss: 3.5570 - val_y1_output_loss: 0.5036 - val_y2_output_loss: 2.9503 - val_y1_output_root_mean_squared_error: 0.7208 - val_y2_output_root_mean_squared_error: 1.7428
# Epoch 102/500
# 614/614 [==============================] - 0s 177us/sample - loss: 3.4747 - y1_output_loss: 0.9034 - y2_output_loss: 2.5416 - y1_output_root_mean_squared_error: 0.9548 - y2_output_root_mean_squared_error: 1.6010 - val_loss: 4.9763 - val_y1_output_loss: 0.5805 - val_y2_output_loss: 4.2406 - val_y1_output_root_mean_squared_error: 0.7729 - val_y2_output_root_mean_squared_error: 2.0926
# Epoch 103/500
# 614/614 [==============================] - 0s 170us/sample - loss: 4.0583 - y1_output_loss: 1.0034 - y2_output_loss: 3.0911 - y1_output_root_mean_squared_error: 1.0055 - y2_output_root_mean_squared_error: 1.7457 - val_loss: 13.0841 - val_y1_output_loss: 1.6360 - val_y2_output_loss: 11.1379 - val_y1_output_root_mean_squared_error: 1.2954 - val_y2_output_root_mean_squared_error: 3.3773
# Epoch 104/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.8110 - y1_output_loss: 0.7007 - y2_output_loss: 2.1210 - y1_output_root_mean_squared_error: 0.8398 - y2_output_root_mean_squared_error: 1.4511 - val_loss: 7.7325 - val_y1_output_loss: 1.4290 - val_y2_output_loss: 6.0677 - val_y1_output_root_mean_squared_error: 1.2134 - val_y2_output_root_mean_squared_error: 2.5021
# Epoch 105/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.9843 - y1_output_loss: 1.1519 - y2_output_loss: 2.7966 - y1_output_root_mean_squared_error: 1.0777 - y2_output_root_mean_squared_error: 1.6801 - val_loss: 4.3821 - val_y1_output_loss: 0.7852 - val_y2_output_loss: 3.4620 - val_y1_output_root_mean_squared_error: 0.9007 - val_y2_output_root_mean_squared_error: 1.8897
# Epoch 106/500
# 614/614 [==============================] - 0s 181us/sample - loss: 5.6256 - y1_output_loss: 1.5184 - y2_output_loss: 4.0699 - y1_output_root_mean_squared_error: 1.2374 - y2_output_root_mean_squared_error: 2.0235 - val_loss: 5.2184 - val_y1_output_loss: 0.7731 - val_y2_output_loss: 4.3144 - val_y1_output_root_mean_squared_error: 0.8926 - val_y2_output_root_mean_squared_error: 2.1028
# Epoch 107/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.4031 - y1_output_loss: 0.4979 - y2_output_loss: 1.9561 - y1_output_root_mean_squared_error: 0.7018 - y2_output_root_mean_squared_error: 1.3822 - val_loss: 14.0979 - val_y1_output_loss: 4.0864 - val_y2_output_loss: 9.7586 - val_y1_output_root_mean_squared_error: 2.0395 - val_y2_output_root_mean_squared_error: 3.1525
# Epoch 108/500
# 614/614 [==============================] - 0s 174us/sample - loss: 3.4782 - y1_output_loss: 0.9065 - y2_output_loss: 2.5798 - y1_output_root_mean_squared_error: 0.9477 - y2_output_root_mean_squared_error: 1.6063 - val_loss: 4.1208 - val_y1_output_loss: 0.9378 - val_y2_output_loss: 3.0699 - val_y1_output_root_mean_squared_error: 0.9827 - val_y2_output_root_mean_squared_error: 1.7762
# Epoch 109/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.6594 - y1_output_loss: 0.9615 - y2_output_loss: 2.7289 - y1_output_root_mean_squared_error: 0.9806 - y2_output_root_mean_squared_error: 1.6425 - val_loss: 13.0164 - val_y1_output_loss: 3.0091 - val_y2_output_loss: 9.6659 - val_y1_output_root_mean_squared_error: 1.7630 - val_y2_output_root_mean_squared_error: 3.1477
# Epoch 110/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.2118 - y1_output_loss: 0.8647 - y2_output_loss: 2.4807 - y1_output_root_mean_squared_error: 0.9245 - y2_output_root_mean_squared_error: 1.5353 - val_loss: 14.3128 - val_y1_output_loss: 2.2743 - val_y2_output_loss: 11.8964 - val_y1_output_root_mean_squared_error: 1.5161 - val_y2_output_root_mean_squared_error: 3.4661
# Epoch 111/500
# 614/614 [==============================] - 0s 179us/sample - loss: 4.9309 - y1_output_loss: 1.2435 - y2_output_loss: 3.6517 - y1_output_root_mean_squared_error: 1.1191 - y2_output_root_mean_squared_error: 1.9180 - val_loss: 4.8625 - val_y1_output_loss: 0.7174 - val_y2_output_loss: 3.9966 - val_y1_output_root_mean_squared_error: 0.8593 - val_y2_output_root_mean_squared_error: 2.0308
# Epoch 112/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.5401 - y1_output_loss: 0.5435 - y2_output_loss: 1.9802 - y1_output_root_mean_squared_error: 0.7391 - y2_output_root_mean_squared_error: 1.4120 - val_loss: 5.1610 - val_y1_output_loss: 1.0640 - val_y2_output_loss: 3.9426 - val_y1_output_root_mean_squared_error: 1.0405 - val_y2_output_root_mean_squared_error: 2.0195
# Epoch 113/500
# 614/614 [==============================] - 0s 178us/sample - loss: 2.1639 - y1_output_loss: 0.4928 - y2_output_loss: 1.6604 - y1_output_root_mean_squared_error: 0.7021 - y2_output_root_mean_squared_error: 1.2927 - val_loss: 3.2656 - val_y1_output_loss: 0.4466 - val_y2_output_loss: 2.7203 - val_y1_output_root_mean_squared_error: 0.6792 - val_y2_output_root_mean_squared_error: 1.6746
# Epoch 114/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.4204 - y1_output_loss: 0.4951 - y2_output_loss: 1.9488 - y1_output_root_mean_squared_error: 0.7037 - y2_output_root_mean_squared_error: 1.3875 - val_loss: 8.4049 - val_y1_output_loss: 1.9840 - val_y2_output_loss: 6.1633 - val_y1_output_root_mean_squared_error: 1.4313 - val_y2_output_root_mean_squared_error: 2.5212
# Epoch 115/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.4100 - y1_output_loss: 0.5473 - y2_output_loss: 1.9193 - y1_output_root_mean_squared_error: 0.7238 - y2_output_root_mean_squared_error: 1.3733 - val_loss: 22.2702 - val_y1_output_loss: 5.2527 - val_y2_output_loss: 16.4940 - val_y1_output_root_mean_squared_error: 2.3272 - val_y2_output_root_mean_squared_error: 4.1054
# Epoch 116/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.9686 - y1_output_loss: 0.9557 - y2_output_loss: 2.9789 - y1_output_root_mean_squared_error: 0.9816 - y2_output_root_mean_squared_error: 1.7335 - val_loss: 3.0619 - val_y1_output_loss: 0.5264 - val_y2_output_loss: 2.4414 - val_y1_output_root_mean_squared_error: 0.7356 - val_y2_output_root_mean_squared_error: 1.5877
# Epoch 117/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.1543 - y1_output_loss: 0.5005 - y2_output_loss: 1.6970 - y1_output_root_mean_squared_error: 0.7023 - y2_output_root_mean_squared_error: 1.2888 - val_loss: 10.1114 - val_y1_output_loss: 2.2059 - val_y2_output_loss: 7.7524 - val_y1_output_root_mean_squared_error: 1.4915 - val_y2_output_root_mean_squared_error: 2.8083
# Epoch 118/500
# 614/614 [==============================] - 0s 169us/sample - loss: 4.6415 - y1_output_loss: 1.4645 - y2_output_loss: 3.1445 - y1_output_root_mean_squared_error: 1.2147 - y2_output_root_mean_squared_error: 1.7793 - val_loss: 2.9293 - val_y1_output_loss: 0.4543 - val_y2_output_loss: 2.3742 - val_y1_output_root_mean_squared_error: 0.6827 - val_y2_output_root_mean_squared_error: 1.5695
# Epoch 119/500
# 614/614 [==============================] - 0s 185us/sample - loss: 2.1766 - y1_output_loss: 0.4300 - y2_output_loss: 1.7604 - y1_output_root_mean_squared_error: 0.6544 - y2_output_root_mean_squared_error: 1.3223 - val_loss: 4.4279 - val_y1_output_loss: 0.4025 - val_y2_output_loss: 3.8857 - val_y1_output_root_mean_squared_error: 0.6462 - val_y2_output_root_mean_squared_error: 2.0026
# Epoch 120/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.3885 - y1_output_loss: 0.5072 - y2_output_loss: 1.8700 - y1_output_root_mean_squared_error: 0.7118 - y2_output_root_mean_squared_error: 1.3718 - val_loss: 3.0342 - val_y1_output_loss: 0.3938 - val_y2_output_loss: 2.5346 - val_y1_output_root_mean_squared_error: 0.6392 - val_y2_output_root_mean_squared_error: 1.6204
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.3880 - y1_output_loss: 0.1205 - y2_output_loss: 0.2654 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5169 - val_loss: 0.8294 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.6335 - val_y1_output_root_mean_squared_error: 0.4285 - val_y2_output_root_mean_squared_error: 0.8036
# Epoch 462/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3560 - y1_output_loss: 0.1108 - y2_output_loss: 0.2450 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.4954 - val_loss: 0.9952 - val_y1_output_loss: 0.1652 - val_y2_output_loss: 0.7955 - val_y1_output_root_mean_squared_error: 0.4132 - val_y2_output_root_mean_squared_error: 0.9080
# Epoch 463/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4003 - y1_output_loss: 0.1192 - y2_output_loss: 0.2780 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5294 - val_loss: 0.7450 - val_y1_output_loss: 0.1377 - val_y2_output_loss: 0.5862 - val_y1_output_root_mean_squared_error: 0.3745 - val_y2_output_root_mean_squared_error: 0.7777
# Epoch 464/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3599 - y1_output_loss: 0.1021 - y2_output_loss: 0.2587 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.5073 - val_loss: 1.0492 - val_y1_output_loss: 0.1534 - val_y2_output_loss: 0.8742 - val_y1_output_root_mean_squared_error: 0.3966 - val_y2_output_root_mean_squared_error: 0.9444
# Epoch 465/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3478 - y1_output_loss: 0.1123 - y2_output_loss: 0.2353 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.4859 - val_loss: 0.8553 - val_y1_output_loss: 0.2238 - val_y2_output_loss: 0.6113 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.7933
# Epoch 466/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.3599 - y1_output_loss: 0.1117 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 0.8375 - val_y1_output_loss: 0.1736 - val_y2_output_loss: 0.6406 - val_y1_output_root_mean_squared_error: 0.4229 - val_y2_output_root_mean_squared_error: 0.8116
# Epoch 467/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3491 - y1_output_loss: 0.1115 - y2_output_loss: 0.2373 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.4867 - val_loss: 0.9753 - val_y1_output_loss: 0.1565 - val_y2_output_loss: 0.7922 - val_y1_output_root_mean_squared_error: 0.3992 - val_y2_output_root_mean_squared_error: 0.9033
# Epoch 468/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3159 - y1_output_loss: 0.1012 - y2_output_loss: 0.2132 - y1_output_root_mean_squared_error: 0.3193 - y2_output_root_mean_squared_error: 0.4625 - val_loss: 0.8690 - val_y1_output_loss: 0.1353 - val_y2_output_loss: 0.7041 - val_y1_output_root_mean_squared_error: 0.3727 - val_y2_output_root_mean_squared_error: 0.8544
# Epoch 469/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3448 - y1_output_loss: 0.1119 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4817 - val_loss: 0.8234 - val_y1_output_loss: 0.1494 - val_y2_output_loss: 0.6494 - val_y1_output_root_mean_squared_error: 0.3896 - val_y2_output_root_mean_squared_error: 0.8195
# Epoch 470/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.3372 - y1_output_loss: 0.1057 - y2_output_loss: 0.2293 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.4803 - val_loss: 0.8425 - val_y1_output_loss: 0.1882 - val_y2_output_loss: 0.6254 - val_y1_output_root_mean_squared_error: 0.4402 - val_y2_output_root_mean_squared_error: 0.8054
# Epoch 471/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.6251 - y1_output_loss: 0.1534 - y2_output_loss: 0.4688 - y1_output_root_mean_squared_error: 0.3929 - y2_output_root_mean_squared_error: 0.6861 - val_loss: 1.1855 - val_y1_output_loss: 0.1738 - val_y2_output_loss: 0.9776 - val_y1_output_root_mean_squared_error: 0.4192 - val_y2_output_root_mean_squared_error: 1.0049
# Epoch 472/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.5311 - y1_output_loss: 0.1383 - y2_output_loss: 0.3995 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.6289 - val_loss: 1.6459 - val_y1_output_loss: 0.3258 - val_y2_output_loss: 1.2961 - val_y1_output_root_mean_squared_error: 0.5752 - val_y2_output_root_mean_squared_error: 1.1468
# Epoch 473/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3604 - y1_output_loss: 0.1164 - y2_output_loss: 0.2418 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.4933 - val_loss: 0.8313 - val_y1_output_loss: 0.1600 - val_y2_output_loss: 0.6496 - val_y1_output_root_mean_squared_error: 0.4059 - val_y2_output_root_mean_squared_error: 0.8164
# Epoch 474/500
# 614/614 [==============================] - 0s 190us/sample - loss: 0.3445 - y1_output_loss: 0.1103 - y2_output_loss: 0.2347 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.4839 - val_loss: 1.1447 - val_y1_output_loss: 0.2159 - val_y2_output_loss: 0.8948 - val_y1_output_root_mean_squared_error: 0.4709 - val_y2_output_root_mean_squared_error: 0.9607
# Epoch 475/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4509 - y1_output_loss: 0.1254 - y2_output_loss: 0.3253 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5701 - val_loss: 1.3180 - val_y1_output_loss: 0.1938 - val_y2_output_loss: 1.0800 - val_y1_output_root_mean_squared_error: 0.4477 - val_y2_output_root_mean_squared_error: 1.0572
# Epoch 476/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4250 - y1_output_loss: 0.1314 - y2_output_loss: 0.2907 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 0.7675 - val_y1_output_loss: 0.1419 - val_y2_output_loss: 0.5997 - val_y1_output_root_mean_squared_error: 0.3821 - val_y2_output_root_mean_squared_error: 0.7884
# Epoch 477/500
# 614/614 [==============================] - 0s 199us/sample - loss: 0.3019 - y1_output_loss: 0.1132 - y2_output_loss: 0.1905 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.4361 - val_loss: 0.8057 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.5932 - val_y1_output_root_mean_squared_error: 0.4453 - val_y2_output_root_mean_squared_error: 0.7794
# Epoch 478/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4088 - y1_output_loss: 0.1187 - y2_output_loss: 0.2894 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5382 - val_loss: 0.9878 - val_y1_output_loss: 0.2094 - val_y2_output_loss: 0.7577 - val_y1_output_root_mean_squared_error: 0.4581 - val_y2_output_root_mean_squared_error: 0.8820
# Epoch 479/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3211 - y1_output_loss: 0.1052 - y2_output_loss: 0.2151 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4649 - val_loss: 1.1306 - val_y1_output_loss: 0.3118 - val_y2_output_loss: 0.7799 - val_y1_output_root_mean_squared_error: 0.5662 - val_y2_output_root_mean_squared_error: 0.9000
# Epoch 480/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3682 - y1_output_loss: 0.1255 - y2_output_loss: 0.2415 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.4924 - val_loss: 0.8228 - val_y1_output_loss: 0.1426 - val_y2_output_loss: 0.6566 - val_y1_output_root_mean_squared_error: 0.3829 - val_y2_output_root_mean_squared_error: 0.8223
# Epoch 481/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3792 - y1_output_loss: 0.1093 - y2_output_loss: 0.2696 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.5194 - val_loss: 1.6248 - val_y1_output_loss: 0.2076 - val_y2_output_loss: 1.3744 - val_y1_output_root_mean_squared_error: 0.4595 - val_y2_output_root_mean_squared_error: 1.1890
# Epoch 482/500
# 614/614 [==============================] - 0s 178us/sample - loss: 0.4312 - y1_output_loss: 0.1321 - y2_output_loss: 0.3004 - y1_output_root_mean_squared_error: 0.3633 - y2_output_root_mean_squared_error: 0.5470 - val_loss: 1.0066 - val_y1_output_loss: 0.1839 - val_y2_output_loss: 0.7869 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.9036
# Epoch 483/500
# 614/614 [==============================] - 0s 201us/sample - loss: 0.3555 - y1_output_loss: 0.1100 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.4949 - val_loss: 0.8102 - val_y1_output_loss: 0.1376 - val_y2_output_loss: 0.6469 - val_y1_output_root_mean_squared_error: 0.3727 - val_y2_output_root_mean_squared_error: 0.8193
# Epoch 484/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.3219 - y1_output_loss: 0.1020 - y2_output_loss: 0.2189 - y1_output_root_mean_squared_error: 0.3206 - y2_output_root_mean_squared_error: 0.4681 - val_loss: 1.0063 - val_y1_output_loss: 0.1797 - val_y2_output_loss: 0.8132 - val_y1_output_root_mean_squared_error: 0.4224 - val_y2_output_root_mean_squared_error: 0.9099
# Epoch 485/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.3032 - y1_output_loss: 0.1056 - y2_output_loss: 0.1978 - y1_output_root_mean_squared_error: 0.3261 - y2_output_root_mean_squared_error: 0.4437 - val_loss: 1.0561 - val_y1_output_loss: 0.1447 - val_y2_output_loss: 0.8830 - val_y1_output_root_mean_squared_error: 0.3829 - val_y2_output_root_mean_squared_error: 0.9536
# Epoch 486/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3397 - y1_output_loss: 0.1111 - y2_output_loss: 0.2282 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.4786 - val_loss: 0.8224 - val_y1_output_loss: 0.1803 - val_y2_output_loss: 0.6225 - val_y1_output_root_mean_squared_error: 0.4289 - val_y2_output_root_mean_squared_error: 0.7990
# Epoch 487/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.3755 - y1_output_loss: 0.1254 - y2_output_loss: 0.2496 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 0.7390 - val_y1_output_loss: 0.1536 - val_y2_output_loss: 0.5642 - val_y1_output_root_mean_squared_error: 0.3976 - val_y2_output_root_mean_squared_error: 0.7622
# Epoch 488/500
# 614/614 [==============================] - 0s 194us/sample - loss: 0.3467 - y1_output_loss: 0.1117 - y2_output_loss: 0.2400 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.4848 - val_loss: 0.8856 - val_y1_output_loss: 0.1634 - val_y2_output_loss: 0.6945 - val_y1_output_root_mean_squared_error: 0.4108 - val_y2_output_root_mean_squared_error: 0.8467
# Epoch 489/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3368 - y1_output_loss: 0.1022 - y2_output_loss: 0.2328 - y1_output_root_mean_squared_error: 0.3209 - y2_output_root_mean_squared_error: 0.4836 - val_loss: 0.7102 - val_y1_output_loss: 0.1259 - val_y2_output_loss: 0.5643 - val_y1_output_root_mean_squared_error: 0.3598 - val_y2_output_root_mean_squared_error: 0.7621
# Epoch 490/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.2799 - y1_output_loss: 0.0964 - y2_output_loss: 0.1821 - y1_output_root_mean_squared_error: 0.3117 - y2_output_root_mean_squared_error: 0.4275 - val_loss: 0.7193 - val_y1_output_loss: 0.1303 - val_y2_output_loss: 0.5685 - val_y1_output_root_mean_squared_error: 0.3651 - val_y2_output_root_mean_squared_error: 0.7655
# Epoch 491/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3374 - y1_output_loss: 0.1087 - y2_output_loss: 0.2267 - y1_output_root_mean_squared_error: 0.3305 - y2_output_root_mean_squared_error: 0.4777 - val_loss: 0.7809 - val_y1_output_loss: 0.1546 - val_y2_output_loss: 0.6118 - val_y1_output_root_mean_squared_error: 0.3929 - val_y2_output_root_mean_squared_error: 0.7915
# Epoch 492/500
# 614/614 [==============================] - 0s 196us/sample - loss: 0.3133 - y1_output_loss: 0.0974 - y2_output_loss: 0.2136 - y1_output_root_mean_squared_error: 0.3125 - y2_output_root_mean_squared_error: 0.4644 - val_loss: 0.8189 - val_y1_output_loss: 0.1600 - val_y2_output_loss: 0.6313 - val_y1_output_root_mean_squared_error: 0.4048 - val_y2_output_root_mean_squared_error: 0.8093
# Epoch 493/500
# 614/614 [==============================] - 0s 195us/sample - loss: 0.3118 - y1_output_loss: 0.1159 - y2_output_loss: 0.1943 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.4417 - val_loss: 0.8023 - val_y1_output_loss: 0.1671 - val_y2_output_loss: 0.6084 - val_y1_output_root_mean_squared_error: 0.4140 - val_y2_output_root_mean_squared_error: 0.7943
# Epoch 494/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4983 - y1_output_loss: 0.1549 - y2_output_loss: 0.3452 - y1_output_root_mean_squared_error: 0.3925 - y2_output_root_mean_squared_error: 0.5867 - val_loss: 1.3430 - val_y1_output_loss: 0.3326 - val_y2_output_loss: 0.9924 - val_y1_output_root_mean_squared_error: 0.5840 - val_y2_output_root_mean_squared_error: 1.0010
# Epoch 495/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.4242 - y1_output_loss: 0.1620 - y2_output_loss: 0.2823 - y1_output_root_mean_squared_error: 0.3831 - y2_output_root_mean_squared_error: 0.5267 - val_loss: 8.3646 - val_y1_output_loss: 3.1562 - val_y2_output_loss: 4.9583 - val_y1_output_root_mean_squared_error: 1.8035 - val_y2_output_root_mean_squared_error: 2.2609
# Epoch 496/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.8145 - y1_output_loss: 0.2699 - y2_output_loss: 0.5409 - y1_output_root_mean_squared_error: 0.5220 - y2_output_root_mean_squared_error: 0.7363 - val_loss: 1.3687 - val_y1_output_loss: 0.1301 - val_y2_output_loss: 1.1919 - val_y1_output_root_mean_squared_error: 0.3661 - val_y2_output_root_mean_squared_error: 1.1112
# Epoch 497/500
# 614/614 [==============================] - 0s 176us/sample - loss: 0.3809 - y1_output_loss: 0.1173 - y2_output_loss: 0.2607 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.5126 - val_loss: 0.8432 - val_y1_output_loss: 0.1274 - val_y2_output_loss: 0.6866 - val_y1_output_root_mean_squared_error: 0.3609 - val_y2_output_root_mean_squared_error: 0.8444
# Epoch 498/500
# 614/614 [==============================] - 0s 188us/sample - loss: 0.3236 - y1_output_loss: 0.1066 - y2_output_loss: 0.2146 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4652 - val_loss: 0.7678 - val_y1_output_loss: 0.1346 - val_y2_output_loss: 0.6100 - val_y1_output_root_mean_squared_error: 0.3677 - val_y2_output_root_mean_squared_error: 0.7954
# Epoch 499/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3089 - y1_output_loss: 0.1037 - y2_output_loss: 0.2031 - y1_output_root_mean_squared_error: 0.3231 - y2_output_root_mean_squared_error: 0.4522 - val_loss: 1.1108 - val_y1_output_loss: 0.3032 - val_y2_output_loss: 0.7824 - val_y1_output_root_mean_squared_error: 0.5531 - val_y2_output_root_mean_squared_error: 0.8972
# Epoch 500/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3671 - y1_output_loss: 0.1189 - y2_output_loss: 0.2507 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5007 - val_loss: 1.1055 - val_y1_output_loss: 0.2540 - val_y2_output_loss: 0.8313 - val_y1_output_root_mean_squared_error: 0.5017 - val_y2_output_root_mean_squared_error: 0.9240

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 40us/sample - loss: 1.1055 - y1_output_loss: 0.2513 - y2_output_loss: 0.8604 - y1_output_root_mean_squared_error: 0.5017 - y2_output_root_mean_squared_error: 0.9240
# Loss = 1.1054531490647947, Y1_loss = 0.25133731961250305, Y1_mse = 0.5017033219337463, Y2_loss = 0.8604055643081665, Y2_mse = 0.9239842295646667

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
